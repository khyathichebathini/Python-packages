# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\91781\\Downloads\\data.csv")
print(df)
# Out:
#       Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 0            NaN         NaN        NaN         NaN     Variables        NaN
# 1        Average  membership        NaN        size           NaN        NaN
# 2       ‘Average     members        NaN         age           NaN        NaN
# 3       ‘Average       years         of  experience           NaN        NaN
# 4       ‘Average      number        NaN  of vessels    registered        NaN
# 5       ‘Average      number        NaN  of vessels  in operation        NaN
# 6       ‘Average      vessel    tonnage         NaN           NaN        NaN
# 7       ‘Average  per member        NaN     revenue           NaN        NaN
# 8       ‘Average      number        NaN  of fishing          days        per
# 9       ‘Average     fishing      hours         per           day        NaN
# 10       Revenue         per    fishing      effort           NaN        NaN
# ...

# %%
df.head(10)
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 0        NaN         NaN        NaN         NaN     Variables        NaN
# 1    Average  membership        NaN        size           NaN        NaN
# 2   ‘Average     members        NaN         age           NaN        NaN
# 3   ‘Average       years         of  experience           NaN        NaN
# 4   ‘Average      number        NaN  of vessels    registered        NaN
# 5   ‘Average      number        NaN  of vessels  in operation        NaN
# 6   ‘Average      vessel    tonnage         NaN           NaN        NaN
# 7   ‘Average  per member        NaN     revenue           NaN        NaN
# 8   ‘Average      number        NaN  of fishing          days        per
# 9   ‘Average     fishing      hours         per           day        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8    FMO Unnamed: 10  Type Unnamed: 12  \
# 0        NaN         im        NaN      5         NaN     a         NaN
# ...

# %%
df.tail(15)
# Out:
#       Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 3       ‘Average       years         of  experience           NaN        NaN
# 4       ‘Average      number        NaN  of vessels    registered        NaN
# 5       ‘Average      number        NaN  of vessels  in operation        NaN
# 6       ‘Average      vessel    tonnage         NaN           NaN        NaN
# 7       ‘Average  per member        NaN     revenue           NaN        NaN
# 8       ‘Average      number        NaN  of fishing          days        per
# 9       ‘Average     fishing      hours         per           day        NaN
# 10       Revenue         per    fishing      effort           NaN        NaN
# 11       Fishing      ground     within        TURF            (%         of
# 12  Solely owned         NaN       TURF       (% of        “yes")        NaN
# 13       Type of     managed        NaN    targeted      species:        NaN
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# count          15         12          6          12          9          2
# unique          8         10          6          11          9          2
# top      ‘Average     number         of  of vessels  Variables        per
# freq            8          3          1           2          1          1
#
#        Unnamed: 6 Unnamed: 7 Unnamed: 8 FMO Unnamed: 10 Type Unnamed: 12  \
# count           4         18          2  17           5   17           1
# unique          4         18          1  17           1   16           1
# top          year         im          |   5           |   83           |
# freq            1          1          2   1           5    2           1
#
#        Unnamed: 13
# count           17
# unique          17
# top              5
# freq             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   15 non-null     object
#  1   Unnamed: 1   12 non-null     object
#  2   Unnamed: 2   6 non-null      object
#  3   Unnamed: 3   12 non-null     object
#  4   Unnamed: 4   9 non-null      object
#  5   Unnamed: 5   2 non-null      object
#  6   Unnamed: 6   4 non-null      object
#  7   Unnamed: 7   18 non-null     object
#  8   Unnamed: 8   2 non-null      object
#  9   FMO          17 non-null     object
#  10  Unnamed: 10  5 non-null      object
#  11  Type         17 non-null     object
#  12  Unnamed: 12  1 non-null      object
#  13  Unnamed: 13  17 non-null     object
# dtypes: object(14)
# memory usage: 2.1+ KB

# %%
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (18, 14)
# 18
# 14

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'FMO',
#  'Unnamed: 10',
#  'Type',
#  'Unnamed: 12',
#  'Unnamed: 13']

# %%
df.isnull()
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         True        True        True        True       False        True
# 1        False       False        True       False        True        True
# 2        False       False        True       False        True        True
# 3        False       False       False       False        True        True
# 4        False       False        True       False       False        True
# 5        False       False        True       False       False        True
# 6        False       False       False        True        True        True
# 7        False       False        True       False        True        True
# 8        False       False        True       False       False       False
# 9        False       False       False       False       False        True
# 10       False       False       False       False        True        True
# ...

# %%
df.isnull().head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0        True        True        True        True       False        True
# 1       False       False        True       False        True        True
# 2       False       False        True       False        True        True
# 3       False       False       False       False        True        True
# 4       False       False        True       False       False        True
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8    FMO  Unnamed: 10   Type  Unnamed: 12  \
# 0        True       False        True  False         True  False         True
# 1        True       False        True  False         True  False         True
# 2        True       False        True  False         True  False         True
# 3        True       False        True  False        False  False         True
# 4        True       False        True  False        False  False         True
#
#    Unnamed: 13
# 0        False
# 1        False
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      3
# Unnamed: 1      6
# Unnamed: 2     12
# Unnamed: 3      6
# Unnamed: 4      9
# Unnamed: 5     16
# Unnamed: 6     14
# Unnamed: 7      0
# Unnamed: 8     16
# FMO             1
# Unnamed: 10    13
# Type            1
# Unnamed: 12    17
# Unnamed: 13     1
# dtype: int64

# %%
df.isna()
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         True        True        True        True       False        True
# 1        False       False        True       False        True        True
# 2        False       False        True       False        True        True
# 3        False       False       False       False        True        True
# 4        False       False        True       False       False        True
# 5        False       False        True       False       False        True
# 6        False       False       False        True        True        True
# 7        False       False        True       False        True        True
# 8        False       False        True       False       False       False
# 9        False       False       False       False       False        True
# 10       False       False       False       False        True        True
# ...

# %%
df['Unnamed: 0']
# Out:
# 0              NaN
# 1          Average
# 2         ‘Average
# 3         ‘Average
# 4         ‘Average
# 5         ‘Average
# 6         ‘Average
# 7         ‘Average
# 8         ‘Average
# 9         ‘Average
# 10         Revenue
# 11         Fishing
# 12    Solely owned
# 13         Type of
# 14      Groundfish
# 15      Crustacean
# 16             NaN
# 17             NaN
# Name: Unnamed: 0, dtype: object

# %%
df[['Unnamed: 0','Unnamed: 1']]
# Out:
#       Unnamed: 0  Unnamed: 1
# 0            NaN         NaN
# 1        Average  membership
# 2       ‘Average     members
# 3       ‘Average       years
# 4       ‘Average      number
# 5       ‘Average      number
# 6       ‘Average      vessel
# 7       ‘Average  per member
# 8       ‘Average      number
# 9       ‘Average     fishing
# 10       Revenue         per
# 11       Fishing      ground
# 12  Solely owned         NaN
# 13       Type of     managed
# 14    Groundfish         NaN
# 15    Crustacean         NaN
# 16           NaN         NaN
# 17           NaN         NaN

# %%
df[['Unnamed: 0','Unnamed: 1']].tail(5)
# Out:
#     Unnamed: 0 Unnamed: 1
# 13     Type of    managed
# 14  Groundfish        NaN
# 15  Crustacean        NaN
# 16         NaN        NaN
# 17         NaN        NaN

# %%
df[df.index==5]
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 5   ‘Average     number        NaN  of vessels  in operation        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8  FMO Unnamed: 10  Type Unnamed: 12  \
# 5        NaN       15.4        NaN  i9|         NaN  21.9         NaN
#
#   Unnamed: 13
# 5        20.4

# %%
df[df.index.isin(range(4,7))]
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 4   ‘Average     number        NaN  of vessels    registered        NaN
# 5   ‘Average     number        NaN  of vessels  in operation        NaN
# 6   ‘Average     vessel    tonnage         NaN           NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8  FMO Unnamed: 10  Type Unnamed: 12  \
# 4        NaN       35.4        NaN  307           |   262         NaN
# 5        NaN       15.4        NaN  i9|         NaN  21.9         NaN
# 6        NaN         92        NaN   37         NaN   3.8         NaN
#
#   Unnamed: 13
# 4         847
# 5        20.4
# 6         6.1

# %%
df.loc[8]
# Out:
# Unnamed: 0       ‘Average
# Unnamed: 1         number
# Unnamed: 2            NaN
# Unnamed: 3     of fishing
# Unnamed: 4           days
# Unnamed: 5            per
# Unnamed: 6           year
# Unnamed: 7          66.0]
# Unnamed: 8            NaN
# FMO                 1189|
# Unnamed: 10           NaN
# Type                 926)
# Unnamed: 12           NaN
# Unnamed: 13         120.2
# Name: 8, dtype: object

# %%
df.loc[9:15]
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 9       ‘Average    fishing      hours        per        day        NaN
# 10       Revenue        per    fishing     effort        NaN        NaN
# 11       Fishing     ground     within       TURF         (%         of
# 12  Solely owned        NaN       TURF      (% of     “yes")        NaN
# 13       Type of    managed        NaN   targeted   species:        NaN
# 14    Groundfish        NaN        NaN        NaN        NaN        NaN
# 15    Crustacean        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8   FMO Unnamed: 10  Type Unnamed: 12  \
# 9         NaN         53        NaN    50         NaN    46         NaN
# 10        NaN      102.4        NaN   104         NaN   126         NaN
# 11     “yes")     e768 |        NaN  852|         NaN   800         NaN
# 12        NaN        667          |   435           |   625         NaN
# ...

# %%
df.iloc[12]
# Out:
# Unnamed: 0     Solely owned
# Unnamed: 1              NaN
# Unnamed: 2             TURF
# Unnamed: 3            (% of
# Unnamed: 4           “yes")
# Unnamed: 5              NaN
# Unnamed: 6              NaN
# Unnamed: 7              667
# Unnamed: 8                |
# FMO                     435
# Unnamed: 10               |
# Type                    625
# Unnamed: 12             NaN
# Unnamed: 13            58.8
# Name: 12, dtype: object

# %%
df.iloc[2:9]
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 2   ‘Average     members        NaN         age           NaN        NaN
# 3   ‘Average       years         of  experience           NaN        NaN
# 4   ‘Average      number        NaN  of vessels    registered        NaN
# 5   ‘Average      number        NaN  of vessels  in operation        NaN
# 6   ‘Average      vessel    tonnage         NaN           NaN        NaN
# 7   ‘Average  per member        NaN     revenue           NaN        NaN
# 8   ‘Average      number        NaN  of fishing          days        per
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8    FMO Unnamed: 10  Type Unnamed: 12  \
# 2        NaN       55.6        NaN   59.6         NaN  59.7         NaN
# 3        NaN       31.6        NaN    342           |   326         NaN
# 4        NaN       35.4        NaN    307           |   262         NaN
# 5        NaN       15.4        NaN    i9|         NaN  21.9         NaN
# ...
